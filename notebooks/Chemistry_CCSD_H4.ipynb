# %%
from symred.chem import xyz_from_pubchem
import numpy as np
from openfermion import FermionOperator
from scipy.sparse.linalg import expm
from openfermion import get_sparse_operator
from symred.chem import Draw_molecule

# %%
xyz_file = '4\n \nH\t0\t0\t0\nH\t2.45366053071732\t0\t0\nH\t2.45366053071732\t2.45366053071732\t0\nH\t0\t2.45366053071732\t0'

viewer = Draw_molecule(xyz_file,
                       width=400,
                       height=400,
                       style="sphere")
viewer.show()
# Out:
# <div id="3dmolviewer_16510563258089988"  style="position: relative; width: 400px; height: 400px">
#         <p id="3dmolwarning_16510563258089988" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16510563258089988 = null;
# var warn = document.getElementById("3dmolwarning_16510563258089988");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16510563258089988 = $3Dmol.createViewer($("#3dmolviewer_16510563258089988"),{backgroundColor:"white"});
# viewer_16510563258089988.zoomTo();
# 	viewer_16510563258089988.addModel("4\n \nH\t0\t0\t0\nH\t2.45366053071732\t0\t0\nH\t2.45366053071732\t2.45366053071732\t0\nH\t0\t2.45366053071732\t0","xyz");
# 	viewer_16510563258089988.setStyle({"sphere": {"radius": 0.2}});
# 	viewer_16510563258089988.zoomTo();
# viewer_16510563258089988.render();
# });
# </script>

# %%
print(xyz_file)
# Out:
# 4
#
# H	0	0	0
# H	2.45366053071732	0	0
# H	2.45366053071732	2.45366053071732	0
# H	0	2.45366053071732	0

# %%
from symred.chem import PySCFDriver

# %%
basis = 'sto-3g' # 'STO-3G'#
convergence = 1e-6
charge= 0
max_hf_cycles=50
ram = 8_000
run_mp2  = False
run_cisd = False
run_ccsd = True
run_fci  = False

# %%
pyscf_obj = PySCFDriver(xyz_file,
                       basis,
                       convergence=convergence,
                       charge=charge,
                       max_ram_memory=ram,
                       max_hf_cycles=max_hf_cycles,
                       
                       run_mp2=run_mp2,
                       run_cisd=run_cisd,
                       run_ccsd=run_ccsd,
                       run_fci=run_fci)

# %%
pyscf_obj.run_pyscf()

# %%
pyscf_obj.pyscf_hf.converged
# Out:
# True

# %%
pyscf_obj.pyscf_ccsd.converged
# Out:
# True

# %%
# T1 = pyscf_obj.pyscf_ccsd.t1
# T2 = pyscf_obj.pyscf_ccsd.t2

# from pyscf import cc
# ccsd = cc.CCSD(pyscf_obj.pyscf_hf)
# ccsd.kernel(t1= T1, t2=T2)
# ccsd.converged

# %%
2*pyscf_obj.pyscf_hf.mol.nao
# Out:
# 8

# %%
from symred.chem import FermionicHamilt

# %%
H_ferm = FermionicHamilt(pyscf_obj.pyscf_hf)

H_ferm.build_operator()

H_ferm.fermionic_molecular_hamiltonian
# Out:
# () 1.1676751516332355
# ((0, 1), (0, 0)) -1.0941167141762014
# ((0, 1), (6, 0)) -0.02518721447269935
# ((1, 1), (1, 0)) -1.0941167141762014
# ((1, 1), (7, 0)) -0.02518721447269935
# ((2, 1), (2, 0)) -1.045835726765513
# ((3, 1), (3, 0)) -1.045835726765513
# ((4, 1), (4, 0)) -1.0458357267655125
# ((5, 1), (5, 0)) -1.0458357267655125
# ((6, 1), (0, 0)) -0.025187214472699386
# ((6, 1), (6, 0)) -1.0047159790974518
# ((7, 1), (1, 0)) -0.025187214472699386
# ((7, 1), (7, 0)) -1.0047159790974518
# ((0, 1), (0, 1), (0, 0), (0, 0)) 0.18176822902112627
# ((0, 1), (0, 1), (0, 0), (6, 0)) -0.027327679168640887
# ((0, 1), (0, 1), (2, 0), (2, 0)) 0.03788747346210273
# ((0, 1), (0, 1), (4, 0), (4, 0)) 0.1144833788422987
# ((0, 1), (0, 1), (6, 0), (0, 0)) -0.027327679168640897
# ((0, 1), (0, 1), (6, 0), (6, 0)) 0.04713286796054257
# ((0, 1), (1, 1), (1, 0), (0, 0)) 0.18176822902112627
# ((0, 1), (1, 1), (1, 0), (6, 0)) -0.027327679168640887
# ((0, 1), (1, 1), (3, 0), (2, 0)) 0.03788747346210273
# ((0, 1), (1, 1), (5, 0), (4, 0)) 0.1144833788422987
# ((0, 1), (1, 1), (7, 0), (0, 0)) -0.027327679168640897
# ((0, 1), (1, 1), (7, 0), (6, 0)) 0.04713286796054257
# ((0, 1), (2, 1), (0, 0), (2, 0)) 0.03788747346210273
# ((0, 1), (2, 1), (2, 0), (0, 0)) 0.13766434946097753
# ((0, 1), (2, 1), (2, 0), (6, 0)) 0.05337383767368697
# ((0, 1), (2, 1), (6, 0), (2, 0)) 0.06682298117855853
# ((0, 1), (3, 1), (1, 0), (2, 0)) 0.03788747346210273
# ((0, 1), (3, 1), (3, 0), (0, 0)) 0.13766434946097753
# ((0, 1), (3, 1), (3, 0), (6, 0)) 0.05337383767368697
# ((0, 1), (3, 1), (7, 0), (2, 0)) 0.06682298117855853
# ((0, 1), (4, 1), (0, 0), (4, 0)) 0.1144833788422987
# ((0, 1), (4, 1), (4, 0), (0, 0)) 0.19889416176217198
# ((0, 1), (4, 1), (4, 0), (6, 0)) -0.05529221260340819
# ((0, 1), (4, 1), (6, 0), (4, 0)) -0.06911365152122236
# ((0, 1), (5, 1), (1, 0), (4, 0)) 0.1144833788422987
# ((0, 1), (5, 1), (5, 0), (0, 0)) 0.19889416176217198
# ((0, 1), (5, 1), (5, 0), (6, 0)) -0.05529221260340819
# ((0, 1), (5, 1), (7, 0), (4, 0)) -0.06911365152122236
# ((0, 1), (6, 1), (0, 0), (0, 0)) -0.027327679168640897
# ((0, 1), (6, 1), (0, 0), (6, 0)) 0.04713286796054257
# ((0, 1), (6, 1), (2, 0), (2, 0)) 0.06682298117855853
# ((0, 1), (6, 1), (4, 0), (4, 0)) -0.06911365152122236
# ((0, 1), (6, 1), (6, 0), (0, 0)) 0.15477060797185788
# ((0, 1), (6, 1), (6, 0), (6, 0)) 0.02543504217123711
# ((0, 1), (7, 1), (1, 0), (0, 0)) -0.027327679168640897
# ((0, 1), (7, 1), (1, 0), (6, 0)) 0.04713286796054257
# ((0, 1), (7, 1), (3, 0), (2, 0)) 0.06682298117855853
# ((0, 1), (7, 1), (5, 0), (4, 0)) -0.06911365152122236
# ((0, 1), (7, 1), (7, 0), (0, 0)) 0.15477060797185788
# ((0, 1), (7, 1), (7, 0), (6, 0)) 0.02543504217123711
# ((1, 1), (0, 1), (0, 0), (1, 0)) 0.18176822902112627
# ((1, 1), (0, 1), (0, 0), (7, 0)) -0.027327679168640887
# ((1, 1), (0, 1), (2, 0), (3, 0)) 0.03788747346210273
# ((1, 1), (0, 1), (4, 0), (5, 0)) 0.1144833788422987
# ((1, 1), (0, 1), (6, 0), (1, 0)) -0.027327679168640897
# ((1, 1), (0, 1), (6, 0), (7, 0)) 0.04713286796054257
# ((1, 1), (1, 1), (1, 0), (1, 0)) 0.18176822902112627
# ((1, 1), (1, 1), (1, 0), (7, 0)) -0.027327679168640887
# ((1, 1), (1, 1), (3, 0), (3, 0)) 0.03788747346210273
# ((1, 1), (1, 1), (5, 0), (5, 0)) 0.1144833788422987
# ((1, 1), (1, 1), (7, 0), (1, 0)) -0.027327679168640897
# ((1, 1), (1, 1), (7, 0), (7, 0)) 0.04713286796054257
# ((1, 1), (2, 1), (0, 0), (3, 0)) 0.03788747346210273
# ((1, 1), (2, 1), (2, 0), (1, 0)) 0.13766434946097753
# ((1, 1), (2, 1), (2, 0), (7, 0)) 0.05337383767368697
# ((1, 1), (2, 1), (6, 0), (3, 0)) 0.06682298117855853
# ((1, 1), (3, 1), (1, 0), (3, 0)) 0.03788747346210273
# ((1, 1), (3, 1), (3, 0), (1, 0)) 0.13766434946097753
# ((1, 1), (3, 1), (3, 0), (7, 0)) 0.05337383767368697
# ((1, 1), (3, 1), (7, 0), (3, 0)) 0.06682298117855853
# ((1, 1), (4, 1), (0, 0), (5, 0)) 0.1144833788422987
# ((1, 1), (4, 1), (4, 0), (1, 0)) 0.19889416176217198
# ((1, 1), (4, 1), (4, 0), (7, 0)) -0.05529221260340819
# ((1, 1), (4, 1), (6, 0), (5, 0)) -0.06911365152122236
# ((1, 1), (5, 1), (1, 0), (5, 0)) 0.1144833788422987
# ((1, 1), (5, 1), (5, 0), (1, 0)) 0.19889416176217198
# ((1, 1), (5, 1), (5, 0), (7, 0)) -0.05529221260340819
# ((1, 1), (5, 1), (7, 0), (5, 0)) -0.06911365152122236
# ((1, 1), (6, 1), (0, 0), (1, 0)) -0.027327679168640897
# ((1, 1), (6, 1), (0, 0), (7, 0)) 0.04713286796054257
# ((1, 1), (6, 1), (2, 0), (3, 0)) 0.06682298117855853
# ((1, 1), (6, 1), (4, 0), (5, 0)) -0.06911365152122236
# ((1, 1), (6, 1), (6, 0), (1, 0)) 0.15477060797185788
# ((1, 1), (6, 1), (6, 0), (7, 0)) 0.02543504217123711
# ((1, 1), (7, 1), (1, 0), (1, 0)) -0.027327679168640897
# ((1, 1), (7, 1), (1, 0), (7, 0)) 0.04713286796054257
# ((1, 1), (7, 1), (3, 0), (3, 0)) 0.06682298117855853
# ((1, 1), (7, 1), (5, 0), (5, 0)) -0.06911365152122236
# ((1, 1), (7, 1), (7, 0), (1, 0)) 0.15477060797185788
# ((1, 1), (7, 1), (7, 0), (7, 0)) 0.02543504217123711
# ((2, 1), (0, 1), (0, 0), (2, 0)) 0.1376643494609775
# ((2, 1), (0, 1), (2, 0), (0, 0)) 0.03788747346210273
# ((2, 1), (0, 1), (2, 0), (6, 0)) 0.06682298117855852
# ((2, 1), (0, 1), (6, 0), (2, 0)) 0.05337383767368699
# ((2, 1), (1, 1), (1, 0), (2, 0)) 0.1376643494609775
# ((2, 1), (1, 1), (3, 0), (0, 0)) 0.03788747346210273
# ((2, 1), (1, 1), (3, 0), (6, 0)) 0.06682298117855852
# ((2, 1), (1, 1), (7, 0), (2, 0)) 0.05337383767368699
# ((2, 1), (2, 1), (0, 0), (0, 0)) 0.03788747346210273
# ((2, 1), (2, 1), (0, 0), (6, 0)) 0.06682298117855852
# ((2, 1), (2, 1), (2, 0), (2, 0)) 0.232754062486315
# ((2, 1), (2, 1), (4, 0), (4, 0)) 0.0001416273575880551
# ((2, 1), (2, 1), (6, 0), (0, 0)) 0.06682298117855853
# ((2, 1), (2, 1), (6, 0), (6, 0)) 0.11854868770523813
# ((2, 1), (3, 1), (1, 0), (0, 0)) 0.03788747346210273
# ((2, 1), (3, 1), (1, 0), (6, 0)) 0.06682298117855852
# ((2, 1), (3, 1), (3, 0), (2, 0)) 0.232754062486315
# ((2, 1), (3, 1), (5, 0), (4, 0)) 0.0001416273575880551
# ((2, 1), (3, 1), (7, 0), (0, 0)) 0.06682298117855853
# ((2, 1), (3, 1), (7, 0), (6, 0)) 0.11854868770523813
# ((2, 1), (4, 1), (2, 0), (4, 0)) 0.0001416273575880551
# ((2, 1), (4, 1), (4, 0), (2, 0)) 0.10728675404930432
# ((2, 1), (5, 1), (3, 0), (4, 0)) 0.0001416273575880551
# ((2, 1), (5, 1), (5, 0), (2, 0)) 0.10728675404930432
# ((2, 1), (6, 1), (0, 0), (2, 0)) 0.05337383767368699
# ((2, 1), (6, 1), (2, 0), (0, 0)) 0.06682298117855853
# ((2, 1), (6, 1), (2, 0), (6, 0)) 0.11854868770523813
# ((2, 1), (6, 1), (6, 0), (2, 0)) 0.2022987488208089
# ((2, 1), (7, 1), (1, 0), (2, 0)) 0.05337383767368699
# ((2, 1), (7, 1), (3, 0), (0, 0)) 0.06682298117855853
# ((2, 1), (7, 1), (3, 0), (6, 0)) 0.11854868770523813
# ((2, 1), (7, 1), (7, 0), (2, 0)) 0.2022987488208089
# ((3, 1), (0, 1), (0, 0), (3, 0)) 0.1376643494609775
# ((3, 1), (0, 1), (2, 0), (1, 0)) 0.03788747346210273
# ((3, 1), (0, 1), (2, 0), (7, 0)) 0.06682298117855852
# ((3, 1), (0, 1), (6, 0), (3, 0)) 0.05337383767368699
# ((3, 1), (1, 1), (1, 0), (3, 0)) 0.1376643494609775
# ((3, 1), (1, 1), (3, 0), (1, 0)) 0.03788747346210273
# ((3, 1), (1, 1), (3, 0), (7, 0)) 0.06682298117855852
# ((3, 1), (1, 1), (7, 0), (3, 0)) 0.05337383767368699
# ((3, 1), (2, 1), (0, 0), (1, 0)) 0.03788747346210273
# ((3, 1), (2, 1), (0, 0), (7, 0)) 0.06682298117855852
# ((3, 1), (2, 1), (2, 0), (3, 0)) 0.232754062486315
# ((3, 1), (2, 1), (4, 0), (5, 0)) 0.0001416273575880551
# ((3, 1), (2, 1), (6, 0), (1, 0)) 0.06682298117855853
# ((3, 1), (2, 1), (6, 0), (7, 0)) 0.11854868770523813
# ((3, 1), (3, 1), (1, 0), (1, 0)) 0.03788747346210273
# ((3, 1), (3, 1), (1, 0), (7, 0)) 0.06682298117855852
# ((3, 1), (3, 1), (3, 0), (3, 0)) 0.232754062486315
# ((3, 1), (3, 1), (5, 0), (5, 0)) 0.0001416273575880551
# ((3, 1), (3, 1), (7, 0), (1, 0)) 0.06682298117855853
# ((3, 1), (3, 1), (7, 0), (7, 0)) 0.11854868770523813
# ((3, 1), (4, 1), (2, 0), (5, 0)) 0.0001416273575880551
# ((3, 1), (4, 1), (4, 0), (3, 0)) 0.10728675404930432
# ((3, 1), (5, 1), (3, 0), (5, 0)) 0.0001416273575880551
# ((3, 1), (5, 1), (5, 0), (3, 0)) 0.10728675404930432
# ((3, 1), (6, 1), (0, 0), (3, 0)) 0.05337383767368699
# ((3, 1), (6, 1), (2, 0), (1, 0)) 0.06682298117855853
# ((3, 1), (6, 1), (2, 0), (7, 0)) 0.11854868770523813
# ((3, 1), (6, 1), (6, 0), (3, 0)) 0.2022987488208089
# ((3, 1), (7, 1), (1, 0), (3, 0)) 0.05337383767368699
# ((3, 1), (7, 1), (3, 0), (1, 0)) 0.06682298117855853
# ((3, 1), (7, 1), (3, 0), (7, 0)) 0.11854868770523813
# ((3, 1), (7, 1), (7, 0), (3, 0)) 0.2022987488208089
# ((4, 1), (0, 1), (0, 0), (4, 0)) 0.198894161762172
# ((4, 1), (0, 1), (4, 0), (0, 0)) 0.1144833788422987
# ((4, 1), (0, 1), (4, 0), (6, 0)) -0.06911365152122237
# ((4, 1), (0, 1), (6, 0), (4, 0)) -0.055292212603408206
# ((4, 1), (1, 1), (1, 0), (4, 0)) 0.198894161762172
# ((4, 1), (1, 1), (5, 0), (0, 0)) 0.1144833788422987
# ((4, 1), (1, 1), (5, 0), (6, 0)) -0.06911365152122237
# ((4, 1), (1, 1), (7, 0), (4, 0)) -0.055292212603408206
# ((4, 1), (2, 1), (2, 0), (4, 0)) 0.10728675404930435
# ((4, 1), (2, 1), (4, 0), (2, 0)) 0.0001416273575880551
# ((4, 1), (3, 1), (3, 0), (4, 0)) 0.10728675404930435
# ((4, 1), (3, 1), (5, 0), (2, 0)) 0.0001416273575880551
# ((4, 1), (4, 1), (0, 0), (0, 0)) 0.1144833788422987
# ((4, 1), (4, 1), (0, 0), (6, 0)) -0.06911365152122237
# ((4, 1), (4, 1), (2, 0), (2, 0)) 0.0001416273575880551
# ((4, 1), (4, 1), (4, 0), (4, 0)) 0.2327540624863148
# ((4, 1), (4, 1), (6, 0), (0, 0)) -0.06911365152122236
# ((4, 1), (4, 1), (6, 0), (6, 0)) 0.04195278232504211
# ((4, 1), (5, 1), (1, 0), (0, 0)) 0.1144833788422987
# ((4, 1), (5, 1), (1, 0), (6, 0)) -0.06911365152122237
# ((4, 1), (5, 1), (3, 0), (2, 0)) 0.0001416273575880551
# ((4, 1), (5, 1), (5, 0), (4, 0)) 0.2327540624863148
# ((4, 1), (5, 1), (7, 0), (0, 0)) -0.06911365152122236
# ((4, 1), (5, 1), (7, 0), (6, 0)) 0.04195278232504211
# ((4, 1), (6, 1), (0, 0), (4, 0)) -0.055292212603408206
# ((4, 1), (6, 1), (4, 0), (0, 0)) -0.06911365152122236
# ((4, 1), (6, 1), (4, 0), (6, 0)) 0.04195278232504211
# ((4, 1), (6, 1), (6, 0), (4, 0)) 0.1410689365196143
# ((4, 1), (7, 1), (1, 0), (4, 0)) -0.055292212603408206
# ((4, 1), (7, 1), (5, 0), (0, 0)) -0.06911365152122236
# ((4, 1), (7, 1), (5, 0), (6, 0)) 0.04195278232504211
# ((4, 1), (7, 1), (7, 0), (4, 0)) 0.1410689365196143
# ((5, 1), (0, 1), (0, 0), (5, 0)) 0.198894161762172
# ((5, 1), (0, 1), (4, 0), (1, 0)) 0.1144833788422987
# ((5, 1), (0, 1), (4, 0), (7, 0)) -0.06911365152122237
# ((5, 1), (0, 1), (6, 0), (5, 0)) -0.055292212603408206
# ((5, 1), (1, 1), (1, 0), (5, 0)) 0.198894161762172
# ((5, 1), (1, 1), (5, 0), (1, 0)) 0.1144833788422987
# ((5, 1), (1, 1), (5, 0), (7, 0)) -0.06911365152122237
# ((5, 1), (1, 1), (7, 0), (5, 0)) -0.055292212603408206
# ((5, 1), (2, 1), (2, 0), (5, 0)) 0.10728675404930435
# ((5, 1), (2, 1), (4, 0), (3, 0)) 0.0001416273575880551
# ((5, 1), (3, 1), (3, 0), (5, 0)) 0.10728675404930435
# ((5, 1), (3, 1), (5, 0), (3, 0)) 0.0001416273575880551
# ((5, 1), (4, 1), (0, 0), (1, 0)) 0.1144833788422987
# ((5, 1), (4, 1), (0, 0), (7, 0)) -0.06911365152122237
# ((5, 1), (4, 1), (2, 0), (3, 0)) 0.0001416273575880551
# ((5, 1), (4, 1), (4, 0), (5, 0)) 0.2327540624863148
# ((5, 1), (4, 1), (6, 0), (1, 0)) -0.06911365152122236
# ((5, 1), (4, 1), (6, 0), (7, 0)) 0.04195278232504211
# ((5, 1), (5, 1), (1, 0), (1, 0)) 0.1144833788422987
# ((5, 1), (5, 1), (1, 0), (7, 0)) -0.06911365152122237
# ((5, 1), (5, 1), (3, 0), (3, 0)) 0.0001416273575880551
# ((5, 1), (5, 1), (5, 0), (5, 0)) 0.2327540624863148
# ((5, 1), (5, 1), (7, 0), (1, 0)) -0.06911365152122236
# ((5, 1), (5, 1), (7, 0), (7, 0)) 0.04195278232504211
# ((5, 1), (6, 1), (0, 0), (5, 0)) -0.055292212603408206
# ((5, 1), (6, 1), (4, 0), (1, 0)) -0.06911365152122236
# ((5, 1), (6, 1), (4, 0), (7, 0)) 0.04195278232504211
# ((5, 1), (6, 1), (6, 0), (5, 0)) 0.1410689365196143
# ((5, 1), (7, 1), (1, 0), (5, 0)) -0.055292212603408206
# ((5, 1), (7, 1), (5, 0), (1, 0)) -0.06911365152122236
# ((5, 1), (7, 1), (5, 0), (7, 0)) 0.04195278232504211
# ((5, 1), (7, 1), (7, 0), (5, 0)) 0.1410689365196143
# ((6, 1), (0, 1), (0, 0), (0, 0)) -0.027327679168640887
# ((6, 1), (0, 1), (0, 0), (6, 0)) 0.15477060797185788
# ((6, 1), (0, 1), (2, 0), (2, 0)) 0.06682298117855852
# ((6, 1), (0, 1), (4, 0), (4, 0)) -0.06911365152122237
# ((6, 1), (0, 1), (6, 0), (0, 0)) 0.04713286796054257
# ((6, 1), (0, 1), (6, 0), (6, 0)) 0.025435042171237106
# ((6, 1), (1, 1), (1, 0), (0, 0)) -0.027327679168640887
# ((6, 1), (1, 1), (1, 0), (6, 0)) 0.15477060797185788
# ((6, 1), (1, 1), (3, 0), (2, 0)) 0.06682298117855852
# ((6, 1), (1, 1), (5, 0), (4, 0)) -0.06911365152122237
# ((6, 1), (1, 1), (7, 0), (0, 0)) 0.04713286796054257
# ((6, 1), (1, 1), (7, 0), (6, 0)) 0.025435042171237106
# ((6, 1), (2, 1), (0, 0), (2, 0)) 0.06682298117855852
# ((6, 1), (2, 1), (2, 0), (0, 0)) 0.05337383767368697
# ((6, 1), (2, 1), (2, 0), (6, 0)) 0.20229874882080884
# ((6, 1), (2, 1), (6, 0), (2, 0)) 0.11854868770523813
# ((6, 1), (3, 1), (1, 0), (2, 0)) 0.06682298117855852
# ((6, 1), (3, 1), (3, 0), (0, 0)) 0.05337383767368697
# ((6, 1), (3, 1), (3, 0), (6, 0)) 0.20229874882080884
# ((6, 1), (3, 1), (7, 0), (2, 0)) 0.11854868770523813
# ((6, 1), (4, 1), (0, 0), (4, 0)) -0.06911365152122237
# ((6, 1), (4, 1), (4, 0), (0, 0)) -0.05529221260340819
# ((6, 1), (4, 1), (4, 0), (6, 0)) 0.14106893651961433
# ((6, 1), (4, 1), (6, 0), (4, 0)) 0.04195278232504211
# ((6, 1), (5, 1), (1, 0), (4, 0)) -0.06911365152122237
# ((6, 1), (5, 1), (5, 0), (0, 0)) -0.05529221260340819
# ((6, 1), (5, 1), (5, 0), (6, 0)) 0.14106893651961433
# ((6, 1), (5, 1), (7, 0), (4, 0)) 0.04195278232504211
# ((6, 1), (6, 1), (0, 0), (0, 0)) 0.04713286796054257
# ((6, 1), (6, 1), (0, 0), (6, 0)) 0.025435042171237106
# ((6, 1), (6, 1), (2, 0), (2, 0)) 0.11854868770523813
# ((6, 1), (6, 1), (4, 0), (4, 0)) 0.04195278232504211
# ((6, 1), (6, 1), (6, 0), (0, 0)) 0.02543504217123711
# ((6, 1), (6, 1), (6, 0), (6, 0)) 0.18848604765837718
# ((6, 1), (7, 1), (1, 0), (0, 0)) 0.04713286796054257
# ((6, 1), (7, 1), (1, 0), (6, 0)) 0.025435042171237106
# ((6, 1), (7, 1), (3, 0), (2, 0)) 0.11854868770523813
# ((6, 1), (7, 1), (5, 0), (4, 0)) 0.04195278232504211
# ((6, 1), (7, 1), (7, 0), (0, 0)) 0.02543504217123711
# ((6, 1), (7, 1), (7, 0), (6, 0)) 0.18848604765837718
# ((7, 1), (0, 1), (0, 0), (1, 0)) -0.027327679168640887
# ((7, 1), (0, 1), (0, 0), (7, 0)) 0.15477060797185788
# ((7, 1), (0, 1), (2, 0), (3, 0)) 0.06682298117855852
# ((7, 1), (0, 1), (4, 0), (5, 0)) -0.06911365152122237
# ((7, 1), (0, 1), (6, 0), (1, 0)) 0.04713286796054257
# ((7, 1), (0, 1), (6, 0), (7, 0)) 0.025435042171237106
# ((7, 1), (1, 1), (1, 0), (1, 0)) -0.027327679168640887
# ((7, 1), (1, 1), (1, 0), (7, 0)) 0.15477060797185788
# ((7, 1), (1, 1), (3, 0), (3, 0)) 0.06682298117855852
# ((7, 1), (1, 1), (5, 0), (5, 0)) -0.06911365152122237
# ((7, 1), (1, 1), (7, 0), (1, 0)) 0.04713286796054257
# ((7, 1), (1, 1), (7, 0), (7, 0)) 0.025435042171237106
# ((7, 1), (2, 1), (0, 0), (3, 0)) 0.06682298117855852
# ((7, 1), (2, 1), (2, 0), (1, 0)) 0.05337383767368697
# ((7, 1), (2, 1), (2, 0), (7, 0)) 0.20229874882080884
# ((7, 1), (2, 1), (6, 0), (3, 0)) 0.11854868770523813
# ((7, 1), (3, 1), (1, 0), (3, 0)) 0.06682298117855852
# ((7, 1), (3, 1), (3, 0), (1, 0)) 0.05337383767368697
# ((7, 1), (3, 1), (3, 0), (7, 0)) 0.20229874882080884
# ((7, 1), (3, 1), (7, 0), (3, 0)) 0.11854868770523813
# ((7, 1), (4, 1), (0, 0), (5, 0)) -0.06911365152122237
# ((7, 1), (4, 1), (4, 0), (1, 0)) -0.05529221260340819
# ((7, 1), (4, 1), (4, 0), (7, 0)) 0.14106893651961433
# ((7, 1), (4, 1), (6, 0), (5, 0)) 0.04195278232504211
# ((7, 1), (5, 1), (1, 0), (5, 0)) -0.06911365152122237
# ((7, 1), (5, 1), (5, 0), (1, 0)) -0.05529221260340819
# ((7, 1), (5, 1), (5, 0), (7, 0)) 0.14106893651961433
# ((7, 1), (5, 1), (7, 0), (5, 0)) 0.04195278232504211
# ((7, 1), (6, 1), (0, 0), (1, 0)) 0.04713286796054257
# ((7, 1), (6, 1), (0, 0), (7, 0)) 0.025435042171237106
# ((7, 1), (6, 1), (2, 0), (3, 0)) 0.11854868770523813
# ((7, 1), (6, 1), (4, 0), (5, 0)) 0.04195278232504211
# ((7, 1), (6, 1), (6, 0), (1, 0)) 0.02543504217123711
# ((7, 1), (6, 1), (6, 0), (7, 0)) 0.18848604765837718
# ((7, 1), (7, 1), (1, 0), (1, 0)) 0.04713286796054257
# ((7, 1), (7, 1), (1, 0), (7, 0)) 0.025435042171237106
# ((7, 1), (7, 1), (3, 0), (3, 0)) 0.11854868770523813
# ((7, 1), (7, 1), (5, 0), (5, 0)) 0.04195278232504211
# ((7, 1), (7, 1), (7, 0), (1, 0)) 0.02543504217123711
# ((7, 1), (7, 1), (7, 0), (7, 0)) 0.18848604765837718

# %%
hf_state = H_ferm.hf_comp_basis_state
hf_state
# Out:
# array([1, 1, 1, 1, 0, 0, 0, 0])

# %%
hf_ket = H_ferm.hf_ket
H_mat = H_ferm.get_sparse_ham()

# %%
from pyscf.cc.addons import spatial2spin

# doubles!

t2 = spatial2spin(pyscf_obj.pyscf_ccsd.t2)
no, nv = t2.shape[1:3]
nmo = no + nv
double_amps = np.zeros((nmo, nmo, nmo, nmo))
double_amps[no:,:no,no:,:no] = .5 * t2.transpose(2,0,3,1)

# %%
# singles

t1 = spatial2spin(pyscf_obj.pyscf_ccsd.t1)
no, nv = t1.shape
nmo = no + nv
ccsd_single_amps = np.zeros((nmo, nmo))
ccsd_single_amps[no:,:no] = t1.T
ccsd_single_amps.shape
# Out:
# (8, 8)

# %%
double_amplitudes_list=[]
double_amplitudes = double_amps
for i, j, k, l in zip(*double_amplitudes.nonzero()):
    if not np.isclose(double_amplitudes[i, j, k, l], 0):
        double_amplitudes_list.append([[i, j, k, l],
                                       double_amplitudes[i, j, k, l]])
    
double_amplitudes_list
# Out:
# [[[4, 0, 5, 1], -0.5456412208879349],
#  [[4, 0, 6, 2], 2.208863578892679e-08],
#  [[4, 0, 7, 3], -1.7451411549163962e-08],
#  [[4, 1, 5, 0], 0.5456412208879349],
#  [[4, 1, 7, 2], 3.954004733809075e-08],
#  [[4, 2, 5, 3], 0.0366321093272368],
#  [[4, 2, 6, 0], -2.208863578892679e-08],
#  [[4, 2, 7, 1], -3.954004733809075e-08],
#  [[4, 3, 5, 2], -0.0366321093272368],
#  [[4, 3, 7, 0], 1.7451411549163962e-08],
#  [[5, 0, 4, 1], 0.5456412208879349],
#  [[5, 0, 6, 3], 3.954004733809075e-08],
#  [[5, 1, 4, 0], -0.5456412208879349],
#  [[5, 1, 6, 2], -1.7451411549163962e-08],
#  [[5, 1, 7, 3], 2.208863578892679e-08],
#  [[5, 2, 4, 3], -0.0366321093272368],
#  [[5, 2, 6, 1], 1.7451411549163962e-08],
#  [[5, 3, 4, 2], 0.0366321093272368],
#  [[5, 3, 6, 0], -3.954004733809075e-08],
#  [[5, 3, 7, 1], -2.208863578892679e-08],
#  [[6, 0, 4, 2], -2.208863578892679e-08],
#  [[6, 0, 5, 3], -3.954004733809075e-08],
#  [[6, 0, 7, 1], 0.0006616412681631195],
#  [[6, 1, 5, 2], 1.7451411549163962e-08],
#  [[6, 1, 7, 0], -0.0006616412681631195],
#  [[6, 2, 4, 0], 2.208863578892679e-08],
#  [[6, 2, 5, 1], -1.7451411549163962e-08],
#  [[6, 2, 7, 3], -0.5515703776378225],
#  [[6, 3, 5, 0], 3.954004733809075e-08],
#  [[6, 3, 7, 2], 0.5515703776378225],
#  [[7, 0, 4, 3], 1.7451411549163962e-08],
#  [[7, 0, 6, 1], -0.0006616412681631195],
#  [[7, 1, 4, 2], -3.954004733809075e-08],
#  [[7, 1, 5, 3], -2.208863578892679e-08],
#  [[7, 1, 6, 0], 0.0006616412681631195],
#  [[7, 2, 4, 1], 3.954004733809075e-08],
#  [[7, 2, 6, 3], 0.5515703776378225],
#  [[7, 3, 4, 0], -1.7451411549163962e-08],
#  [[7, 3, 5, 1], 2.208863578892679e-08],
#  [[7, 3, 6, 2], -0.5515703776378225]]

# %%
single_amplitudes_list = []
for i, j in zip(*ccsd_single_amps.nonzero()):
    single_amplitudes_list.append([[i, j], ccsd_single_amps[i, j]])

single_amplitudes_list
# Out:
# [[[4, 0], -3.912181678103236e-15],
#  [[4, 2], -6.110293692729721e-08],
#  [[5, 1], -3.912181678103236e-15],
#  [[5, 3], -6.110293692729721e-08],
#  [[6, 0], -0.4435278092467373],
#  [[6, 2], 4.3248127744901715e-15],
#  [[7, 1], -0.4435278092467373],
#  [[7, 3], 4.3248127744901715e-15]]

# %%
generator_t2 = FermionOperator()

# Add double excitations
for (i, j, k, l), t_ijkl in double_amplitudes_list:
    i, j, k, l = int(i), int(j), int(k), int(l)
    generator_t2 += FermionOperator(((i, 1), (j, 0), (k, 1), (l, 0)), t_ijkl)
#     if anti_hermitian:
#         generator += FermionOperator(((l, 1), (k, 0), (j, 1), (i, 0)),
#                                      -t_ijkl)

# %%
generator_t1 = FermionOperator()
for (i, j), t_ij in single_amplitudes_list:
    i, j = int(i), int(j)
    generator_t1 += FermionOperator(((i, 1), (j, 0)), t_ij)

# %%
T = generator_t1 + 0.5*generator_t2

ccsd_ansatz = expm(get_sparse_operator(T, n_qubits=H_ferm.n_qubits))

# %%
ccsd_ket =  ccsd_ansatz @ hf_ket
hf_ket.conj().T @ H_mat @ ccsd_ket
# Out:
# (-1.8261563137028727+0j)

# %%
pyscf_obj.pyscf_ccsd.e_tot
# Out:
# -1.8261563137028722

# %%
# intermediate normalization
hf_ket.conj().T  @ ccsd_ket
# Out:
# (1+0j)

# %%
normalized_state = ccsd_ket / np.sqrt(ccsd_ket.conj().T@ccsd_ket)

E_from_vec = normalized_state.conj().T @ H_mat @ normalized_state
E_from_vec
# Out:
# (-1.7418931709154082+0j)

# %%
abs(pyscf_obj.pyscf_ccsd.e_tot - E_from_vec)
# Out:
# 0.08426314278746405

# %%
for ind, amp in enumerate(normalized_state):
    if not np.isclose(amp, 0):
        binary_string = np.binary_repr(ind, width=H_ferm.n_qubits)
        print(f'{amp}|{binary_string}>')
# Out:
# (0.5276099995527699+0j)|00001111>
# (-1.8433902498537798e-08+0j)|00011011>
# (1.8433902498537798e-08+0j)|00100111>
# (0.08576206597664797+0j)|00110011>
# (-0.4725840345446496+0j)|00111100>
# (0.014071962063256225+0j)|01001110>
# (2.250980991942932e-08+0j)|01100110>
# (0.19207141387290994+0j)|01110010>
# (-0.014071962063256225+0j)|10001101>
# (2.2509809919429316e-08+0j)|10011001>
# (-0.19207141387290996+0j)|10110001>
# (-0.47771932255267385+0j)|11000011>
# (0.03172735005536297+0j)|11001100>
# (2.6460860497891207e-08+0j)|11011000>
# (-2.6460860497891207e-08+0j)|11100100>
# (0.43305382406373405+0j)|11110000>

# %%
trotter_op = np.eye(2**H_ferm.n_qubits)
for op in list(generator_t2):
    trotter_op*= expm(get_sparse_operator(op, n_qubits=H_ferm.n_qubits))

    
ccsd_trotter = trotter_op @ hf_ket


normalized_trotter = ccsd_trotter / np.sqrt(ccsd_trotter.conj().T@ccsd_trotter)

normalized_trotter.conj().T @ H_mat @ normalized_trotter
# Out:
# (-1.5162206379375986+0j)

# %%
for ind, amp in enumerate(normalized_trotter):
    if not np.isclose(amp, 0):
        binary_string = np.binary_repr(ind, width=H_ferm.n_qubits)
        print(f'{amp}|{binary_string}>')
# Out:
# (0.8277926697224702+0j)|00001111>
# (0.0004549263477769256+0j)|00110011>
# (-0.3751679040580851+0j)|00111100>
# (-1.5187538762098153e-08+0j)|01011010>
# (2.7186649612082093e-08+0j)|01100110>
# (-1.199911084998394e-08+0j)|01101001>
# (-1.199911084998394e-08+0j)|10010110>
# (2.7186649612082093e-08+0j)|10011001>
# (-1.5187538762098153e-08+0j)|10100101>
# (-0.3792446292495347+0j)|11000011>
# (0.025187231373688078+0j)|11001100>
# (0.1718931276157827+0j)|11110000>

# %%
ccsd_ansatz.shape
# Out:
# (256, 256)

# %%
zero_state = np.zeros((H_mat.shape[0],1))
zero_state[0]=1

# T = generator_t1 + 0.5*generator_t2
hf_ket.conj().T @ np.linalg.pinv(ccsd_ansatz.todense()) @ H_mat @ ccsd_ansatz @ hf_ket
# Out:
# matrix([[-1.82615631+0.j]])

# %%
vals, vecs = np.linalg.eigh(H_mat.todense())
min(vals)
# Out:
# -1.8743108952541805

# %%
H_rot =  np.linalg.pinv(ccsd_ansatz.todense()) @ H_mat.todense() @ ccsd_ansatz 
# H_rot =  H_mat.todense() @ ccsd_ansatz 
# H_rot = np.linalg.pinv(ccsd_ansatz.todense()) @ H_mat.todense() 

vals, vecs = np.linalg.eigh(H_rot)
min(vals)
# Out:
# -2.096006827134742

# %%
ccsd_ansatz_inv = expm(get_sparse_operator(-1*T, n_qubits=H_ferm.n_qubits))
H_rot =  ccsd_ansatz_inv @ H_mat @ ccsd_ansatz 

vals, vecs = np.linalg.eigh(H_rot.todense())
print(min(vals))
# Out:
# -2.0960068271347416

# %%
hf_ket.conj().T @ H_rot @ hf_ket
# Out:
# (-1.826156313702873+0j)

# %%
from symred.symplectic_form import PauliwordOp
conv_dic = {0: 'I', 1:'X'}
P = ''.join([conv_dic[i] for i in H_ferm.hf_comp_basis_state])
HF_ansatz = PauliwordOp([P],[1])
print(HF_ansatz)

HF_ans_mat = HF_ansatz.to_sparse_matrix
# Out:
# 1.0000000000+0.0000000000j XXXXIIII

# %%
np.allclose(HF_ans_mat.conj().T.todense(),  HF_ans_mat.todense())
# Out:
# True

# %%
np.allclose(HF_ans_mat@zero_state, hf_ket.reshape(-1,1))
# Out:
# True

# %%
# H_rot =  HF_ans_mat.conj().T @ ccsd_ansatz_inv @ H_mat @ ccsd_ansatz @ HF_ans_mat
# vals, vecs = np.linalg.eigh(H_rot.todense())
# print(min(vals))


fin_state = ccsd_ansatz @ HF_ans_mat@zero_state
fin_state.conj().T @ H_mat @ fin_state
# Out:
# array([[-9.28833265+0.j]])

# %%
zero_state = np.zeros((H_mat.shape[0],1))
zero_state[0]=1

zero_state.conj().T @HF_ans_mat.conj().T @ np.linalg.pinv(ccsd_ansatz.todense()) @ H_mat @ ccsd_ansatz @ HF_ans_mat@ zero_state
# Out:
# matrix([[-1.82615631+0.j]])

# %%
zero_state.conj().T @HF_ans_mat.conj().T @ ccsd_ansatz.todense().conj().T @ H_mat @ ccsd_ansatz @ HF_ans_mat@ zero_state
# Out:
# matrix([[-9.28833265+0.j]])

# %%
state1 = ccsd_ansatz @ HF_ans_mat@ zero_state

state2 = state1.conj().T

state3 = zero_state.conj().T @HF_ans_mat.conj().T @ np.linalg.pinv(ccsd_ansatz.todense())

print(np.allclose(state2,
           state3))

state3 @ state1
# Out:
# False
# matrix([[1.+0.j]])

# %%
from openfermion import hermitian_conjugated
T = generator_t1 + 0.5*generator_t2

T_dagger = hermitian_conjugated(T)

ccsd_ansatz = expm(get_sparse_operator(T, n_qubits=H_ferm.n_qubits))
